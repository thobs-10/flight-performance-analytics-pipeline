# %% [markdown]
# ## Exploring the data

# %%
import polars as pl

# %%
# read the data from data folder
import os
from pathlib import Path

# Use environment variable or fall back to a path relative to the project root
data_dir = os.environ.get(
    "FLIGHT_DATA_DIR",
    str(Path(__file__).parents[1] / "data" / "ot_delaycause1_DL")
    if "__file__" in dir()
    else str(Path.cwd().parent / "data" / "ot_delaycause1_DL"),
)
csv_path = Path(data_dir) / "Airline_Delay_Cause.csv"
df = pl.read_csv(str(csv_path))
df.sample(5)

# %%
df

# %%
# hget column names
df.columns
# Out:
# ['year',
#  'month',
#  'carrier',
#  'carrier_name',
#  'airport',
#  'airport_name',
#  'arr_flights',
#  'arr_del15',
#  'carrier_ct',
#  'weather_ct',
#  'nas_ct',
#  'security_ct',
#  'late_aircraft_ct',
#  'arr_cancelled',
#  'arr_diverted',
#  'arr_delay',
#  'carrier_delay',
#  'weather_delay',
#  'nas_delay',
#  'security_delay',
#  'late_aircraft_delay']
