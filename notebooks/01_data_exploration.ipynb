# %% [markdown]
# ## Exploring the data

# %%
import polars as pl

# %%
# read the data from data folder
df = pl.read_csv(
    "/Users/thobelasixpence/Documents/de-projects/flight-performance-analytics-pipeline/data/ot_delaycause1_DL/Airline_Delay_Cause.csv"
)
df.sample(5)
# Out:
# shape: (5, 21)
# ┌──────┬───────┬─────────┬──────────────┬───┬──────────────┬───────────┬─────────────┬─────────────┐
# │ year ┆ month ┆ carrier ┆ carrier_name ┆ … ┆ weather_dela ┆ nas_delay ┆ security_de ┆ late_aircra │
# │ ---  ┆ ---   ┆ ---     ┆ ---          ┆   ┆ y            ┆ ---       ┆ lay         ┆ ft_delay    │
# │ i64  ┆ i64   ┆ str     ┆ str          ┆   ┆ ---          ┆ f64       ┆ ---         ┆ ---         │
# │      ┆       ┆         ┆              ┆   ┆ f64          ┆           ┆ f64         ┆ f64         │
# ╞══════╪═══════╪═════════╪══════════════╪═══╪══════════════╪═══════════╪═════════════╪═════════════╡
# │ 2025 ┆ 11    ┆ DL      ┆ Delta Air    ┆ … ┆ 0.0          ┆ 74.0      ┆ 0.0         ┆ 56.0        │
# │      ┆       ┆         ┆ Lines        ┆   ┆              ┆           ┆             ┆             │
# │      ┆       ┆         ┆ Network      ┆   ┆              ┆           ┆             ┆             │
# ...

# %%
df

# %%
# hget column names
df.columns
# Out:
# ['year',
#  'month',
#  'carrier',
#  'carrier_name',
#  'airport',
#  'airport_name',
#  'arr_flights',
#  'arr_del15',
#  'carrier_ct',
#  'weather_ct',
#  'nas_ct',
#  'security_ct',
#  'late_aircraft_ct',
#  'arr_cancelled',
#  'arr_diverted',
#  'arr_delay',
#  'carrier_delay',
#  'weather_delay',
#  'nas_delay',
#  'security_delay',
#  'late_aircraft_delay']
